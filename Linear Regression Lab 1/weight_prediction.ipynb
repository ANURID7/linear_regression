# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge  # Use Ridge if you want regularization
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
import pandas as pd

df = pd.read_excel('weights.xlsx')

print(df.head())
# Out:
#    Weight  Height  Age Gender
# 0      79    1.80   35   Male
# 1      69    1.68   39   Male
# 2      73    1.82   25   Male
# 3      95    1.87   27   Male
# 4      82    1.55   18   Male

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})

# %%
X = df[['Height', 'Age', 'Gender']]
y = df['Weight']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
model = LinearRegression()
model.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_scaled)

# %%
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Squared Error: 38.91
# Root Mean Squared Error: 6.24
# R² Score: 0.6317

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='Perfect Prediction')

plt.title('Predicted vs Actual Body Weight')
plt.xlabel('Actual Weight')
plt.ylabel('Predicted Weight')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
